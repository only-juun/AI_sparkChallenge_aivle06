# %% [markdown]
# # 대회 개요

# %% [markdown]
# ## 주제
# - 공기압축기 이상 판단(제4회 2023 연구개발특구 AI SPARK 챌린지)
# - 산업기기 피로도를 예측하는 문제
#
# ## 모델 조건
# - 모델링은 비지도학습 방식으로 진행
# - 입력된 데이터를 정상(0), 이상(1)로 구분하는 이진 분류 모델
# - 시간 단위로 생성되는 입력 데이터에 대하여 판정을 수행할 수 있는 모델
# - 신규 데이터로 학습/개선이 가능한 모델
# - 외부 공공 데이터 사용 가능
#
# ## 기타 중요 내용
# - 반드시 리더보드상의 순위 기록에 해당되는 버전의 코드/모델 가중치를 제출
# - 소스코드 내의 모든 무작위성은 seed 설정을 통해 통제

# %% [markdown]
# # 데이터 불러오기

# %% [markdown]
# * train_data
#     * 학습용 데이터
#     * 모두 정상 case로 이루어짐
#     * (2463 * 8)
# * test_data
#     * 평가용 데이터
#     * 정상 case와 이상 case가 함께 포함됨
#     * (7389 * 8)
#
# * 구성
#     - air_inflow: 공기 흡입 유량 (^3/min)
#     - air_end_temp: 공기 말단 온도 (°C)
#     - out_pressure: 토출 압력 (Mpa)
#     - motor_current: 모터 전류 (A)
#     - motor_rpm: 모터 회전수 (rpm)
#     - motor_temp: 모터 온도 (°C)
#     - motor_vibe: 모터 진동 (mm/s)
#     - type: 설비 번호
#         - 설비 번호 [0, 4, 5, 6, 7]: 30HP(마력)
#         - 설비 번호 1: 20HP
#         - 설비 번호 2: 10HP
#         - 설비 번호 3: 50HP

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train_data = pd.read_csv("https://raw.githubusercontent.com/only-juun/AI_spark_challenge/main/split_by_type/new_train_data_0.csv", index_col=0)
test_data = pd.read_csv("https://raw.githubusercontent.com/only-juun/AI_spark_challenge/main/split_by_type/new_test_data_0.csv", index_col=0)

# %%
drop_col = 'type'
train_data0 = train_data.drop(drop_col, axis=1)
test_data0 = test_data.drop(drop_col, axis=1)

# %%
test_data0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1296 entries, 0 to 1295
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   air_inflow     1296 non-null   float64
#  1   air_end_temp   1296 non-null   float64
#  2   out_pressure   1296 non-null   float64
#  3   motor_current  1296 non-null   float64
#  4   motor_rpm      1296 non-null   float64
#  5   motor_temp     1296 non-null   float64
#  6   motor_vibe     1296 non-null   float64
# dtypes: float64(7)
# memory usage: 81.0 KB

# %% [markdown]
# # 데이터 전처리

# %% [markdown]
# ### 새로운 Feature 추가하기

# %%
# 모터 전류 당 공기 유량은 압축기의 효율성
train_data0['air_inflow_per_motor_current'] = train_data0['air_inflow'] / train_data0['motor_current']	
test_data0['air_inflow_per_motor_current'] = test_data0['air_inflow'] / test_data0['motor_current']

# # 압축기와 모터의 상태를 모두 고려한 압축기 효율1
# new_train_data7['Compressor_Efficiency1'] = new_train_data7['out_pressure'] * new_train_data7['air_inflow'] / new_train_data7['motor_current'] / 3.5168 / new_train_data7['hp']
# test_data7['Compressor_Efficiency1'] = test_data7['out_pressure'] * test_data7['air_inflow'] / test_data7['motor_current'] / 3.5168 / test_data7['hp']

# # 압축기와 모터의 상태를 모두 고려한 압축기 효율2
# new_train_data7['Motor_Efficiency'] = (new_train_data7['motor_current'] * new_train_data7['motor_rpm'] * new_train_data7['hp']) / (746 * 1000)
# test_data7['Motor_Efficiency'] = (test_data7['motor_current'] * test_data7['motor_rpm'] * test_data7['hp']) / (746 * 1000)

# # 압축기의 효율2
# new_train_data7['Compressor_Efficiency2'] = (new_train_data7['out_pressure'] * new_train_data7['air_inflow'] * (new_train_data7['air_end_temp'] - 25)) / (new_train_data7['motor_current'] * new_train_data7['motor_vibe'] * new_train_data7['hp'] * 3.6)
# test_data7['Compressor_Efficiency2'] = (test_data7['out_pressure'] * test_data7['air_inflow'] * (test_data7['air_end_temp'] - 25)) / (test_data7['motor_current'] * test_data7['motor_vibe'] * test_data7['hp'] * 3.6)

# 압축기의 배출량
train_data0['Discharge_Volume'] = (train_data0['air_inflow'] / 60) * ((train_data0['air_end_temp'] + 273) / 273) * (train_data0['out_pressure'] / 1.01325)
test_data0['Discharge_Volume'] = (test_data0['air_inflow'] / 60) * ((test_data0['air_end_temp'] + 273) / 273) * (test_data0['out_pressure'] / 1.01325)

# # 공기의 밀도
# train_data7['air_density'] = train_data7['out_pressure'] / (287 * (train_data7['air_end_temp'] + 273))
# test_data7['air_density'] = test_data7['out_pressure'] / (287 * (test_data7['air_end_temp'] + 273))

# %%
df_train = train_data0.copy()
df_test = test_data0.copy()

# %%
# # 이전 시간대 대비 차이 계산 (delta)
# df_delta = train_data6.diff(periods=1)
# df_delta.columns = [col+"_delta" for col in train_data6.columns]

# # 이전 시간대 대비 변화율 계산 (delta rate)
# df_delta_rate = train_data6.pct_change(periods=1)
# df_delta_rate.columns = [col+"_delta_rate" for col in train_data6.columns]

# # 이동평균 계산 (moving average)
# window_size = 3 # 윈도우 크기
# df_ma3 = train_data6.rolling(window_size).mean()
# df_ma3.columns = [col+"_ma3" for col in train_data6.columns]

# # 이동평균 계산 (moving average)
# window_size = 5 # 윈도우 크기
# df_ma5 = train_data6.rolling(window_size).mean()
# df_ma5.columns = [col+"_ma5" for col in train_data6.columns]

# # 이동평균 계산 (moving average)
# window_size = 10 # 윈도우 크기
# df_ma10 = train_data6.rolling(window_size).mean()
# df_ma10.columns = [col+"_ma10" for col in train_data6.columns]

# 새로운 feature들을 데이터프레임에 추가하기
df_train = pd.concat([train_data6, df_delta, df_delta_rate, df_ma3], axis=1)

# 맨 처음과 맨 마지막 데이터의 결측치 처리하기
df_train = df_train.fillna(method="bfill").fillna(method="ffill")

# %%
# # 이전 시간대 대비 차이 계산 (delta)
# df_delta = test_data6.diff(periods=1)
# df_delta.columns = [col+"_delta" for col in test_data6.columns]

# # 이전 시간대 대비 변화율 계산 (delta rate)
# df_delta_rate = test_data6.pct_change(periods=1)
# df_delta_rate.columns = [col+"_delta_rate" for col in test_data6.columns]

# # 이동평균 계산 (moving average)
# window_size = 3 # 윈도우 크기
# df_ma3 = test_data6.rolling(window_size).mean()
# df_ma3.columns = [col+"_ma3" for col in test_data6.columns]

# # 이동평균 계산 (moving average)
# window_size = 5 # 윈도우 크기
# df_ma5 = test_data6.rolling(window_size).mean()
# df_ma5.columns = [col+"_ma5" for col in test_data6.columns]

# # 이동평균 계산 (moving average)
# window_size = 10 # 윈도우 크기
# df_ma10 = test_data6.rolling(window_size).mean()
# df_ma10.columns = [col+"_ma10" for col in test_data6.columns]

# 새로운 feature들을 데이터프레임에 추가하기
df_test = pd.concat([test_data6, df_delta, df_delta_rate, df_ma3], axis=1)

# 맨 처음과 맨 마지막 데이터의 결측치 처리하기
df_test = df_test.fillna(method="bfill").fillna(method="ffill")

# %% [markdown]
# # 모델링

# %% [markdown]
# ### PyTorch 모델링

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split
import random

# %%
def fix_seed(random_seed):
    torch.manual_seed(random_seed)
    torch.cuda.manual_seed(random_seed)
    torch.cuda.manual_seed_all(random_seed)  # if use multi-GPU
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    os.environ["PYTHONHASHSEED"] = str(random_seed)
    np.random.seed(random_seed)
    random.seed(random_seed)
fix_seed(42)

# %%
class Autoencoder(nn.Module):
    def __init__(self):
        super(Autoencoder, self).__init__()
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, hidden_dim1),
            nn.ReLU(),
            nn.Linear(hidden_dim1, encoding_dim),
            nn.ReLU()
        )
        self.decoder = nn.Sequential(
            nn.Linear(encoding_dim, hidden_dim1),
            nn.ReLU(),
            nn.Linear(hidden_dim1, input_dim),
        )

    def forward(self, x):
        x = self.encoder(x)
        x = self.decoder(x)
        return x

# %%
# class Autoencoder(nn.Module):
#     def __init__(self):
#         super(Autoencoder, self).__init__()
#         self.encoder = nn.Sequential(
#             nn.Linear(input_dim, hidden_dim1),
#             nn.ReLU(),
#             nn.Linear(hidden_dim1, hidden_dim2),
#             nn.ReLU(),
#             nn.Linear(hidden_dim2, encoding_dim), # 추가된 히든 레이어
#             nn.ReLU() # 추가된 히든 레이어
#         )
#         self.decoder = nn.Sequential(
#             nn.Linear(encoding_dim, hidden_dim2), # 추가된 히든 레이어
#             nn.ReLU(), # 추가된 히든 레이어
#             nn.Linear(hidden_dim2, hidden_dim1),
#             nn.ReLU(),
#             nn.Linear(hidden_dim1, input_dim),
#         )

#     def forward(self, x):
#         x = self.encoder(x)
#         x = self.decoder(x)
#         return x

# %%
# Preprocess the data
scaler = StandardScaler()
train_data_scaled = scaler.fit_transform(df_train)
test_data_scaled = scaler.transform(df_test)

# Convert numpy arrays to torch tensors
train_data_scaled = torch.from_numpy(train_data_scaled).float()
test_data_scaled = torch.from_numpy(test_data_scaled).float()

# %%
# Define the autoencoder architecture
input_dim = train_data_scaled.shape[1]
encoding_dim = 64
hidden_dim1 = 32
hidden_dim2 = 64

model = Autoencoder()

# Compile and train the autoencoder with early stopping
optimizer = torch.optim.Adam(model.parameters())
criterion = nn.MSELoss()

best_loss = float('inf')
patience = 100
count = 0

print(model)
# Out:
# Autoencoder(
#   (encoder): Sequential(
#     (0): Linear(in_features=9, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=32, out_features=64, bias=True)
#     (3): ReLU()
#   )
#   (decoder): Sequential(
#     (0): Linear(in_features=64, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=32, out_features=9, bias=True)
#   )
# )

# %%
model_name = 'type0_timeSeries_plus2_ver3'

# %%
for epoch in range(10000):
    train_loss = 0
    for i in range(0, len(train_data_scaled), 32):
        inputs = train_data_scaled[i:i+32]
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, inputs)
        train_loss += loss.item()
        loss.backward()
        optimizer.step()
    train_loss /= len(train_data_scaled)/32
    with torch.no_grad():
        val_loss = criterion(model(test_data_scaled), test_data_scaled)
        if val_loss < best_loss:
            count = 0
            best_loss = val_loss
            torch.save(model.state_dict(), f"{model_name}.pth")
        else:
            count += 1
        if count >= patience:
            print("Early stopping!")
            break
    if epoch:
        print(f"Epoch {epoch}, train loss: {train_loss}, val loss: {val_loss.item()}")
# Out:
# Epoch 1, train loss: 0.7302413075058548, val loss: 134.608642578125
# Epoch 2, train loss: 0.40925017882276465, val loss: 119.490966796875
# Epoch 3, train loss: 0.15127911501460606, val loss: 103.59941864013672
# Epoch 4, train loss: 0.0850969315678985, val loss: 80.59466552734375
# Epoch 5, train loss: 0.049673960992583525, val loss: 53.29176330566406
# Epoch 6, train loss: 0.02192528966676306, val loss: 26.81136131286621
# Epoch 7, train loss: 0.006887210050114879, val loss: 13.141942977905273
# Epoch 8, train loss: 0.002967204415687808, val loss: 10.445454597473145
# Epoch 9, train loss: 0.0014290162620859013, val loss: 9.816362380981445
# Epoch 10, train loss: 0.0008799138509116515, val loss: 8.558521270751953
# Epoch 11, train loss: 0.0006471431137200583, val loss: 7.973675727844238
# Epoch 12, train loss: 0.0005149441766897562, val loss: 7.981888771057129
# Epoch 13, train loss: 0.00042949637389500385, val loss: 7.824574947357178
# Epoch 14, train loss: 0.0003731922910514253, val loss: 7.75825309753418
# Epoch 15, train loss: 0.0003317498119065055, val loss: 7.630477428436279
# Epoch 16, train loss: 0.000300712772446719, val loss: 7.526504039764404
# Epoch 17, train loss: 0.00027591885709962635, val loss: 7.353230953216553
# Epoch 18, train loss: 0.0002546402344402547, val loss: 7.233554363250732
# Epoch 19, train loss: 0.0002350442513556185, val loss: 7.028226375579834
# Epoch 20, train loss: 0.0002177050671350487, val loss: 6.868061065673828
# Epoch 21, train loss: 0.00020140482822036439, val loss: 6.619542598724365
# Epoch 22, train loss: 0.00018829170019469329, val loss: 6.415287494659424
# Epoch 23, train loss: 0.00017561482888629176, val loss: 6.170351028442383
# Epoch 24, train loss: 0.0001661878103968101, val loss: 6.028651714324951
# Epoch 25, train loss: 0.0001572764993869458, val loss: 5.893044948577881
# Epoch 26, train loss: 0.00015073804684949141, val loss: 5.733038902282715
# Epoch 27, train loss: 0.00014489743032889373, val loss: 5.618824481964111
# Epoch 28, train loss: 0.00013831715235331407, val loss: 5.466575622558594
# Epoch 29, train loss: 0.00013402718684153147, val loss: 5.329730033874512
# Epoch 30, train loss: 0.00012963467452209443, val loss: 5.202779293060303
# Epoch 31, train loss: 0.00012535418554088446, val loss: 5.082352638244629
# Epoch 32, train loss: 0.00012150051231771984, val loss: 4.969891548156738
# Epoch 33, train loss: 0.00011784330126829445, val loss: 4.852912425994873
# Epoch 34, train loss: 0.0001140227158666002, val loss: 4.734506130218506
# Epoch 35, train loss: 0.00011043818839998157, val loss: 4.612666606903076
# Epoch 36, train loss: 0.00010665937130667132, val loss: 4.481079578399658
# Epoch 37, train loss: 0.00010333189102648585, val loss: 4.358907699584961
# Epoch 38, train loss: 0.00010033837288911282, val loss: 4.241879463195801
# Epoch 39, train loss: 9.745509763619068e-05, val loss: 4.123293876647949
# Epoch 40, train loss: 9.480888763425389e-05, val loss: 4.018464088439941
# Epoch 41, train loss: 9.221860899641697e-05, val loss: 3.9163143634796143
# Epoch 42, train loss: 9.017037976903978e-05, val loss: 3.8280348777770996
# Epoch 43, train loss: 8.81734872732691e-05, val loss: 3.7424156665802
# Epoch 44, train loss: 8.62168903781653e-05, val loss: 3.668858289718628
# Epoch 45, train loss: 8.41914249273638e-05, val loss: 3.5968499183654785
# Epoch 46, train loss: 8.226860356646487e-05, val loss: 3.527552843093872
# Epoch 47, train loss: 8.037544332047994e-05, val loss: 3.463261604309082
# Epoch 48, train loss: 7.852961129241589e-05, val loss: 3.4076199531555176
# Epoch 49, train loss: 7.66159641056287e-05, val loss: 3.3557076454162598
# Epoch 50, train loss: 7.48049076517216e-05, val loss: 3.3066775798797607
# Epoch 51, train loss: 7.291110604354698e-05, val loss: 3.2555012702941895
# Epoch 52, train loss: 7.103517418727279e-05, val loss: 3.218208074569702
# Epoch 53, train loss: 6.93298958746406e-05, val loss: 3.1737918853759766
# Epoch 54, train loss: 6.761187439594694e-05, val loss: 3.1398303508758545
# Epoch 55, train loss: 6.594399639181103e-05, val loss: 3.102557420730591
# Epoch 56, train loss: 6.44279808275988e-05, val loss: 3.0639688968658447
# Epoch 57, train loss: 6.294975955151367e-05, val loss: 3.032658338546753
# Epoch 58, train loss: 6.153398135211319e-05, val loss: 3.003657817840576
# Epoch 59, train loss: 6.0178249475063273e-05, val loss: 2.969191074371338
# Epoch 60, train loss: 5.900048590437682e-05, val loss: 2.9359681606292725
# Epoch 61, train loss: 5.779091292492079e-05, val loss: 2.9045872688293457
# Epoch 62, train loss: 5.6695911755216206e-05, val loss: 2.868809700012207
# Epoch 63, train loss: 5.558879584660409e-05, val loss: 2.839684247970581
# Epoch 64, train loss: 5.460946461729085e-05, val loss: 2.805771827697754
# Epoch 65, train loss: 5.3642226299012284e-05, val loss: 2.7784056663513184
# Epoch 66, train loss: 5.2712888982905836e-05, val loss: 2.746427536010742
# Epoch 67, train loss: 5.1826040294987184e-05, val loss: 2.7188048362731934
# Epoch 68, train loss: 5.100565559351472e-05, val loss: 2.689743757247925
# Epoch 69, train loss: 5.0191663763986e-05, val loss: 2.6629719734191895
# Epoch 70, train loss: 4.947425003154893e-05, val loss: 2.634243965148926
# Epoch 71, train loss: 4.8710217621798314e-05, val loss: 2.607079267501831
# Epoch 72, train loss: 4.8050528372793146e-05, val loss: 2.580580472946167
# Epoch 73, train loss: 4.7346629596884464e-05, val loss: 2.558082342147827
# Epoch 74, train loss: 4.680620245549276e-05, val loss: 2.5269248485565186
# Epoch 75, train loss: 4.6077804182897567e-05, val loss: 2.501007080078125
# Epoch 76, train loss: 4.561274545267224e-05, val loss: 2.4763405323028564
# Epoch 77, train loss: 4.490758658869675e-05, val loss: 2.4555046558380127
# Epoch 78, train loss: 4.457253413016183e-05, val loss: 2.4315531253814697
# Epoch 79, train loss: 4.4014747901302246e-05, val loss: 2.4135401248931885
# Epoch 80, train loss: 4.3636118789436296e-05, val loss: 2.390031337738037
# Epoch 81, train loss: 4.308069024032361e-05, val loss: 2.3672454357147217
# Epoch 82, train loss: 4.273868290948923e-05, val loss: 2.3510024547576904
# Epoch 83, train loss: 4.250413069341987e-05, val loss: 2.326462507247925
# Epoch 84, train loss: 4.2265322446366085e-05, val loss: 2.304051637649536
# Epoch 85, train loss: 4.211843244977192e-05, val loss: 2.281531810760498
# Epoch 86, train loss: 4.1888539541374756e-05, val loss: 2.263211727142334
# Epoch 87, train loss: 4.187906354976197e-05, val loss: 2.2422914505004883
# Epoch 88, train loss: 4.176478089195573e-05, val loss: 2.2181899547576904
# Epoch 89, train loss: 4.182724889553221e-05, val loss: 2.2026000022888184
# Epoch 90, train loss: 4.167452088613236e-05, val loss: 2.179560899734497
# Epoch 91, train loss: 4.1894631673737116e-05, val loss: 2.1688408851623535
# Epoch 92, train loss: 4.1775163818211125e-05, val loss: 2.1545937061309814
# Epoch 93, train loss: 4.2086027355657686e-05, val loss: 2.136622190475464
# Epoch 94, train loss: 4.1997078369604424e-05, val loss: 2.1215739250183105
# Epoch 95, train loss: 4.213284652602548e-05, val loss: 2.1060009002685547
# Epoch 96, train loss: 4.237298182690413e-05, val loss: 2.0914533138275146
# Epoch 97, train loss: 4.2417623195366037e-05, val loss: 2.076056957244873
# Epoch 98, train loss: 4.269594231758405e-05, val loss: 2.0677623748779297
# Epoch 99, train loss: 4.2954319791601005e-05, val loss: 2.0538015365600586
# Epoch 100, train loss: 4.3232022748001056e-05, val loss: 2.0403363704681396
# Epoch 101, train loss: 4.347705921477259e-05, val loss: 2.0339319705963135
# Epoch 102, train loss: 4.3928064702346024e-05, val loss: 2.023101329803467
# Epoch 103, train loss: 4.4381463441014705e-05, val loss: 2.012235403060913
# Epoch 104, train loss: 4.506601517614736e-05, val loss: 2.0034825801849365
# Epoch 105, train loss: 4.5692707418412385e-05, val loss: 1.9918917417526245
# Epoch 106, train loss: 4.656397747263933e-05, val loss: 1.983472466468811
# Epoch 107, train loss: 4.731425401082056e-05, val loss: 1.9763233661651611
# Epoch 108, train loss: 4.841099305647529e-05, val loss: 1.966047763824463
# Epoch 109, train loss: 4.929802526021376e-05, val loss: 1.9635577201843262
# Epoch 110, train loss: 5.0260365781098325e-05, val loss: 1.9570324420928955
# Epoch 111, train loss: 5.120352094915385e-05, val loss: 1.9546526670455933
# Epoch 112, train loss: 5.239227876127525e-05, val loss: 1.9529504776000977
# Epoch 113, train loss: 5.320210092813121e-05, val loss: 1.9534064531326294
# Epoch 114, train loss: 5.396294592948699e-05, val loss: 1.9517933130264282
# Epoch 115, train loss: 5.499245728262597e-05, val loss: 1.9498056173324585
# Epoch 116, train loss: 5.581062605078505e-05, val loss: 1.950164556503296
# Epoch 117, train loss: 5.6569800546168594e-05, val loss: 1.9481810331344604
# Epoch 118, train loss: 5.662334539617101e-05, val loss: 1.9474339485168457
# Epoch 119, train loss: 5.701477628597921e-05, val loss: 1.9459238052368164
# Epoch 120, train loss: 5.6355653214268386e-05, val loss: 1.9476336240768433
# Epoch 121, train loss: 5.577393555237601e-05, val loss: 1.9460457563400269
# Epoch 122, train loss: 5.496910657880276e-05, val loss: 1.9461669921875
# Epoch 123, train loss: 5.393935619698217e-05, val loss: 1.9503158330917358
# Epoch 124, train loss: 5.271607989453952e-05, val loss: 1.9472781419754028
# Epoch 125, train loss: 5.163559520345492e-05, val loss: 1.9471993446350098
# Epoch 126, train loss: 5.0942788355449147e-05, val loss: 1.9446979761123657
# Epoch 127, train loss: 5.019394895363668e-05, val loss: 1.9466809034347534
# Epoch 128, train loss: 4.983729875810376e-05, val loss: 1.9414983987808228
# Epoch 129, train loss: 4.9080695909516954e-05, val loss: 1.9409434795379639
# Epoch 130, train loss: 4.925521945416996e-05, val loss: 1.939881443977356
# Epoch 131, train loss: 4.9393067456549034e-05, val loss: 1.9387112855911255
# Epoch 132, train loss: 4.991792930350466e-05, val loss: 1.9377851486206055
# Epoch 133, train loss: 5.0182288288380264e-05, val loss: 1.9359346628189087
# Epoch 134, train loss: 5.116573299380468e-05, val loss: 1.9352803230285645
# Epoch 135, train loss: 5.207507597838735e-05, val loss: 1.9303739070892334
# Epoch 136, train loss: 5.333448253050274e-05, val loss: 1.9286272525787354
# Epoch 137, train loss: 5.473931944127091e-05, val loss: 1.9284677505493164
# Epoch 138, train loss: 5.633072012440405e-05, val loss: 1.927355408668518
# Epoch 139, train loss: 5.788474771651198e-05, val loss: 1.9134588241577148
# Epoch 140, train loss: 5.907110284574123e-05, val loss: 1.9048494100570679
# Epoch 141, train loss: 6.056965449479995e-05, val loss: 1.9100329875946045
# Epoch 142, train loss: 6.127139015545793e-05, val loss: 1.915367603302002
# Epoch 143, train loss: 6.183513431568388e-05, val loss: 1.9213578701019287
# Epoch 144, train loss: 6.187557462706334e-05, val loss: 1.9208760261535645
# Epoch 145, train loss: 6.145247634439902e-05, val loss: 1.9205029010772705
# Epoch 146, train loss: 5.888995117318161e-05, val loss: 1.9146931171417236
# Epoch 147, train loss: 5.645507701922691e-05, val loss: 1.9094884395599365
# Epoch 148, train loss: 5.429404579141798e-05, val loss: 1.9077081680297852
# Epoch 149, train loss: 5.2180138515756914e-05, val loss: 1.9082362651824951
# Epoch 150, train loss: 5.0720605132583943e-05, val loss: 1.9091739654541016
# Epoch 151, train loss: 4.966137984646829e-05, val loss: 1.9103938341140747
# Epoch 152, train loss: 4.8973539917453845e-05, val loss: 1.9086557626724243
# Epoch 153, train loss: 4.865984010393731e-05, val loss: 1.908981204032898
# Epoch 154, train loss: 4.819855220611552e-05, val loss: 1.9079639911651611
# Epoch 155, train loss: 4.849684544886394e-05, val loss: 1.9066287279129028
# Epoch 156, train loss: 4.903246170013315e-05, val loss: 1.9035223722457886
# Epoch 157, train loss: 5.029787590265861e-05, val loss: 1.9037213325500488
# Epoch 158, train loss: 5.202434207334321e-05, val loss: 1.9022555351257324
# Epoch 159, train loss: 5.4140342534217916e-05, val loss: 1.9035714864730835
# Epoch 160, train loss: 5.6762718385370034e-05, val loss: 1.9008246660232544
# Epoch 161, train loss: 5.989569830557297e-05, val loss: 1.9021292924880981
# Epoch 162, train loss: 6.337172561432924e-05, val loss: 1.8972104787826538
# Epoch 163, train loss: 6.547626320820268e-05, val loss: 1.894195795059204
# Epoch 164, train loss: 6.400479792824222e-05, val loss: 1.886277675628662
# Epoch 165, train loss: 5.988313838585142e-05, val loss: 1.8774628639221191
# Epoch 166, train loss: 5.424689610393856e-05, val loss: 1.8764073848724365
# Epoch 167, train loss: 4.8587236287184406e-05, val loss: 1.8760981559753418
# Epoch 168, train loss: 4.355189230409451e-05, val loss: 1.8728121519088745
# Epoch 169, train loss: 3.9868897012503886e-05, val loss: 1.8773490190505981
# Epoch 170, train loss: 3.745129800302459e-05, val loss: 1.875410556793213
# Epoch 171, train loss: 3.57762471173407e-05, val loss: 1.877487301826477
# Epoch 172, train loss: 3.55634047419126e-05, val loss: 1.8785804510116577
# Epoch 173, train loss: 3.582981500787557e-05, val loss: 1.8785135746002197
# Epoch 174, train loss: 3.673580889611643e-05, val loss: 1.8802894353866577
# Epoch 175, train loss: 3.8299440887015034e-05, val loss: 1.881693959236145
# Epoch 176, train loss: 4.0518280810728254e-05, val loss: 1.880359411239624
# Epoch 177, train loss: 4.321747932138991e-05, val loss: 1.8826903104782104
# Epoch 178, train loss: 4.664791830927478e-05, val loss: 1.8828154802322388
# Epoch 179, train loss: 5.0245523097045305e-05, val loss: 1.883533000946045
# Epoch 180, train loss: 5.452198955161428e-05, val loss: 1.8828767538070679
# Epoch 181, train loss: 5.990159250494024e-05, val loss: 1.8787522315979004
# Epoch 182, train loss: 6.563173384940321e-05, val loss: 1.8796387910842896
# Epoch 183, train loss: 7.145779212199462e-05, val loss: 1.8713001012802124
# Epoch 184, train loss: 7.633136893100864e-05, val loss: 1.8630651235580444
# Epoch 185, train loss: 8.018027788407549e-05, val loss: 1.8425606489181519
# Epoch 186, train loss: 8.089738899057179e-05, val loss: 1.8270784616470337
# Epoch 187, train loss: 7.758595448750485e-05, val loss: 1.8126205205917358
# Epoch 188, train loss: 7.367286363862352e-05, val loss: 1.8027479648590088
# Epoch 189, train loss: 6.8370083614287e-05, val loss: 1.7868784666061401
# Epoch 190, train loss: 6.216950512478231e-05, val loss: 1.7836054563522339
# Epoch 191, train loss: 5.6534817607219644e-05, val loss: 1.7889270782470703
# Epoch 192, train loss: 5.16393603767803e-05, val loss: 1.7952555418014526
# Epoch 193, train loss: 4.715639443020336e-05, val loss: 1.7961314916610718
# Epoch 194, train loss: 4.3768785097334466e-05, val loss: 1.7934980392456055
# Epoch 195, train loss: 4.12880282157049e-05, val loss: 1.7867610454559326
# Epoch 196, train loss: 3.911853733976992e-05, val loss: 1.7825874090194702
# Epoch 197, train loss: 3.772057230148844e-05, val loss: 1.7789884805679321
# Epoch 198, train loss: 3.710448180316706e-05, val loss: 1.7743453979492188
# Epoch 199, train loss: 3.6964579151201715e-05, val loss: 1.7721948623657227
# Epoch 200, train loss: 3.740930238833513e-05, val loss: 1.7728281021118164
# Epoch 201, train loss: 3.820203696873418e-05, val loss: 1.7744261026382446
# Epoch 202, train loss: 4.0013959531077286e-05, val loss: 1.771274209022522
# Epoch 203, train loss: 4.222758084156171e-05, val loss: 1.7730700969696045
# Epoch 204, train loss: 4.561101269684042e-05, val loss: 1.7761669158935547
# Epoch 205, train loss: 4.925724513466573e-05, val loss: 1.7761151790618896
# Epoch 206, train loss: 5.3916730124641346e-05, val loss: 1.7748548984527588
# Epoch 207, train loss: 5.9742645707619546e-05, val loss: 1.7779512405395508
# Epoch 208, train loss: 6.606196270526939e-05, val loss: 1.7773264646530151
# Epoch 209, train loss: 7.255587385130909e-05, val loss: 1.7796461582183838
# Epoch 210, train loss: 7.991775028467937e-05, val loss: 1.7846410274505615
# Epoch 211, train loss: 8.837708635298811e-05, val loss: 1.7867742776870728
# Epoch 212, train loss: 9.41479691526318e-05, val loss: 1.7716354131698608
# Epoch 213, train loss: 9.736094755310289e-05, val loss: 1.7445989847183228
# Epoch 214, train loss: 9.935621360286691e-05, val loss: 1.7088489532470703
# Epoch 215, train loss: 9.99004626431054e-05, val loss: 1.6837444305419922
# Epoch 216, train loss: 9.700176842333922e-05, val loss: 1.6599079370498657
# Epoch 217, train loss: 9.359294873084528e-05, val loss: 1.6358598470687866
# Epoch 218, train loss: 8.591907222850111e-05, val loss: 1.6316291093826294
# Epoch 219, train loss: 7.830086488630277e-05, val loss: 1.6347851753234863
# Epoch 220, train loss: 6.973045863021441e-05, val loss: 1.6487780809402466
# Epoch 221, train loss: 6.036786847592642e-05, val loss: 1.665834665298462
# Epoch 222, train loss: 5.245795438423994e-05, val loss: 1.678513526916504
# Epoch 223, train loss: 4.6084206351898264e-05, val loss: 1.6887950897216797
# Epoch 224, train loss: 4.094427155602413e-05, val loss: 1.704666256904602
# Epoch 225, train loss: 3.69912153541076e-05, val loss: 1.707166075706482
# Epoch 226, train loss: 3.3446113337521197e-05, val loss: 1.7076486349105835
# Epoch 227, train loss: 3.045448358062896e-05, val loss: 1.7136284112930298
# Epoch 228, train loss: 2.823889075511101e-05, val loss: 1.715415120124817
# Epoch 229, train loss: 2.653881273107362e-05, val loss: 1.7173045873641968
# Epoch 230, train loss: 2.527568829935734e-05, val loss: 1.7157939672470093
# Epoch 231, train loss: 2.4344824716401354e-05, val loss: 1.7170084714889526
# Epoch 232, train loss: 2.4074819386307218e-05, val loss: 1.7147589921951294
# Epoch 233, train loss: 2.4031858764054186e-05, val loss: 1.715103268623352
# Epoch 234, train loss: 2.4301025809513198e-05, val loss: 1.7171663045883179
# Epoch 235, train loss: 2.49797241714852e-05, val loss: 1.7175333499908447
# Epoch 236, train loss: 2.6024500348958775e-05, val loss: 1.7160496711730957
# Epoch 237, train loss: 2.7358774214344857e-05, val loss: 1.7115569114685059
# Epoch 238, train loss: 2.9327090656065763e-05, val loss: 1.7072103023529053
# Epoch 239, train loss: 3.1364555238892705e-05, val loss: 1.7077529430389404
# Epoch 240, train loss: 3.4068891384069706e-05, val loss: 1.7073123455047607
# Epoch 241, train loss: 3.7324946552635755e-05, val loss: 1.7093349695205688
# Epoch 242, train loss: 4.166215809096617e-05, val loss: 1.6960242986679077
# Epoch 243, train loss: 4.6758340936826746e-05, val loss: 1.6903572082519531
# Epoch 244, train loss: 5.1436750962036764e-05, val loss: 1.6917083263397217
# Epoch 245, train loss: 5.6709876743197026e-05, val loss: 1.6830388307571411
# Epoch 246, train loss: 6.142327657909375e-05, val loss: 1.6676840782165527
# Epoch 247, train loss: 6.59996218962112e-05, val loss: 1.647720456123352
# Epoch 248, train loss: 6.896856508252245e-05, val loss: 1.6358999013900757
# Epoch 249, train loss: 7.038655247823853e-05, val loss: 1.628861665725708
# Epoch 250, train loss: 6.96172627848918e-05, val loss: 1.620275616645813
# Epoch 251, train loss: 6.629419200450045e-05, val loss: 1.6057475805282593
# Epoch 252, train loss: 5.95685010517223e-05, val loss: 1.6199547052383423
# Epoch 253, train loss: 5.197387535763146e-05, val loss: 1.64299738407135
# Epoch 254, train loss: 4.5730447810557154e-05, val loss: 1.6581207513809204
# Epoch 255, train loss: 4.0257468450969704e-05, val loss: 1.6760551929473877
# Epoch 256, train loss: 3.695053048970833e-05, val loss: 1.6923471689224243
# Epoch 257, train loss: 3.530262471974345e-05, val loss: 1.7015047073364258
# Epoch 258, train loss: 3.4971057444905726e-05, val loss: 1.706591248512268
# Epoch 259, train loss: 3.586842730227444e-05, val loss: 1.7143418788909912
# Epoch 260, train loss: 3.666052213736327e-05, val loss: 1.7225584983825684
# Epoch 261, train loss: 3.818505245834348e-05, val loss: 1.7174837589263916
# Epoch 262, train loss: 3.935531263037033e-05, val loss: 1.714987874031067
# Epoch 263, train loss: 4.0576288248067375e-05, val loss: 1.7154951095581055
# Epoch 264, train loss: 4.167948416714488e-05, val loss: 1.7105004787445068
# Epoch 265, train loss: 4.2447789585114355e-05, val loss: 1.7058379650115967
# Epoch 266, train loss: 4.335870013434302e-05, val loss: 1.6953272819519043
# Epoch 267, train loss: 4.468504105009035e-05, val loss: 1.6909149885177612
# Epoch 268, train loss: 4.559324440412672e-05, val loss: 1.6861695051193237
# Epoch 269, train loss: 4.7523058903472566e-05, val loss: 1.6709568500518799
# Epoch 270, train loss: 4.8361976546908e-05, val loss: 1.6692816019058228
# Epoch 271, train loss: 4.9754828608086054e-05, val loss: 1.6696230173110962
# Epoch 272, train loss: 5.072968471924671e-05, val loss: 1.664939045906067
# Epoch 273, train loss: 5.136503737217195e-05, val loss: 1.6629085540771484
# Epoch 274, train loss: 5.120278446055535e-05, val loss: 1.665560007095337
# Epoch 275, train loss: 5.125209268212698e-05, val loss: 1.6687589883804321
# Epoch 276, train loss: 5.001660099002981e-05, val loss: 1.6735925674438477
# Epoch 277, train loss: 4.801046870178888e-05, val loss: 1.679294466972351
# Epoch 278, train loss: 4.520086602294921e-05, val loss: 1.6890746355056763
# Epoch 279, train loss: 4.307895303807325e-05, val loss: 1.700378179550171
# Epoch 280, train loss: 4.0857907690763195e-05, val loss: 1.7044342756271362
# Epoch 281, train loss: 3.8806212547502514e-05, val loss: 1.7164199352264404
# Epoch 282, train loss: 3.705753692042048e-05, val loss: 1.7274348735809326
# Epoch 283, train loss: 3.53507154310743e-05, val loss: 1.72835373878479
# Epoch 284, train loss: 3.400031683095558e-05, val loss: 1.7334188222885132
# Epoch 285, train loss: 3.294542680291838e-05, val loss: 1.7380387783050537
# Epoch 286, train loss: 3.232421322199689e-05, val loss: 1.7387852668762207
# Epoch 287, train loss: 3.154749369800643e-05, val loss: 1.736952543258667
# Epoch 288, train loss: 3.119414180185197e-05, val loss: 1.7357736825942993
# Epoch 289, train loss: 3.1138163952467344e-05, val loss: 1.7337331771850586
# Epoch 290, train loss: 3.145046233570341e-05, val loss: 1.7328808307647705
# Epoch 291, train loss: 3.175187480842901e-05, val loss: 1.728886365890503
# Epoch 292, train loss: 3.245658647049115e-05, val loss: 1.7241015434265137
# Epoch 293, train loss: 3.314146063833808e-05, val loss: 1.715284824371338
# Epoch 294, train loss: 3.41124577971641e-05, val loss: 1.7069816589355469
# Epoch 295, train loss: 3.535631091195952e-05, val loss: 1.6938560009002686
# Epoch 296, train loss: 3.677224244542972e-05, val loss: 1.6866739988327026
# Epoch 297, train loss: 3.791076327346403e-05, val loss: 1.6774206161499023
# Epoch 298, train loss: 3.902772503486766e-05, val loss: 1.6641236543655396
# Epoch 299, train loss: 4.0365952170557444e-05, val loss: 1.6588268280029297
# Epoch 300, train loss: 4.1653100871136065e-05, val loss: 1.6510275602340698
# Epoch 301, train loss: 4.3045221429093986e-05, val loss: 1.6416429281234741
# Epoch 302, train loss: 4.399082172312774e-05, val loss: 1.6365751028060913
# Epoch 303, train loss: 4.4200680955934026e-05, val loss: 1.6294732093811035
# Epoch 304, train loss: 4.389704783399658e-05, val loss: 1.6266067028045654
# Epoch 305, train loss: 4.341489262447727e-05, val loss: 1.6272348165512085
# Epoch 306, train loss: 4.257365165998366e-05, val loss: 1.623947262763977
# Epoch 307, train loss: 4.1118501367573456e-05, val loss: 1.627678394317627
# Epoch 308, train loss: 3.9610602403559756e-05, val loss: 1.6329739093780518
# Epoch 309, train loss: 3.84877969702723e-05, val loss: 1.6339025497436523
# Epoch 310, train loss: 3.716818604583817e-05, val loss: 1.633849859237671
# Epoch 311, train loss: 3.528545575035322e-05, val loss: 1.6339998245239258
# Epoch 312, train loss: 3.356911084092981e-05, val loss: 1.6387361288070679
# Epoch 313, train loss: 3.2515989274812726e-05, val loss: 1.6449259519577026
# Epoch 314, train loss: 3.18199493415671e-05, val loss: 1.6439735889434814
# Epoch 315, train loss: 3.104074925499002e-05, val loss: 1.6502065658569336
# Epoch 316, train loss: 3.069639556256502e-05, val loss: 1.653401494026184
# Epoch 317, train loss: 3.104863288980495e-05, val loss: 1.6532504558563232
# Epoch 318, train loss: 3.182191014477414e-05, val loss: 1.654557466506958
# Epoch 319, train loss: 3.290756366267386e-05, val loss: 1.6516350507736206
# Epoch 320, train loss: 3.420866630255693e-05, val loss: 1.6478772163391113
# Epoch 321, train loss: 3.527328805864306e-05, val loss: 1.6438121795654297
# Epoch 322, train loss: 3.6433535839293016e-05, val loss: 1.6385151147842407
# Epoch 323, train loss: 3.7886155445853044e-05, val loss: 1.6328123807907104
# Epoch 324, train loss: 3.932552580307755e-05, val loss: 1.626487135887146
# Epoch 325, train loss: 4.060881070068313e-05, val loss: 1.6167185306549072
# Epoch 326, train loss: 4.1071521991398185e-05, val loss: 1.603110432624817
# Epoch 327, train loss: 4.0943723299143904e-05, val loss: 1.5911369323730469
# Epoch 328, train loss: 4.142237580877177e-05, val loss: 1.574654459953308
# Epoch 329, train loss: 4.1797494810048695e-05, val loss: 1.561561942100525
# Epoch 330, train loss: 4.289047164665708e-05, val loss: 1.5545355081558228
# Epoch 331, train loss: 4.527969442144105e-05, val loss: 1.5469543933868408
# Epoch 332, train loss: 4.8364117295326046e-05, val loss: 1.5364854335784912
# Epoch 333, train loss: 5.2588253715334256e-05, val loss: 1.5209970474243164
# Epoch 334, train loss: 5.950990399233652e-05, val loss: 1.5140644311904907
# Epoch 335, train loss: 7.0405172327473e-05, val loss: 1.5170140266418457
# Epoch 336, train loss: 8.520041538523165e-05, val loss: 1.5185413360595703
# Epoch 337, train loss: 9.106018734638821e-05, val loss: 1.5217820405960083
# Epoch 338, train loss: 7.494571818150925e-05, val loss: 1.52118980884552
# Epoch 339, train loss: 4.6501080726523435e-05, val loss: 1.5311046838760376
# Epoch 340, train loss: 3.0323370554941465e-05, val loss: 1.5610475540161133
# Epoch 341, train loss: 2.614934554138152e-05, val loss: 1.5888071060180664
# Epoch 342, train loss: 2.589405132177355e-05, val loss: 1.6062206029891968
# Epoch 343, train loss: 2.459062522609235e-05, val loss: 1.6269973516464233
# Epoch 344, train loss: 2.0808252075868142e-05, val loss: 1.6468924283981323
# Epoch 345, train loss: 1.7217195986800276e-05, val loss: 1.6643545627593994
# Epoch 346, train loss: 1.6146542259742057e-05, val loss: 1.6791396141052246
# Epoch 347, train loss: 2.135180969802335e-05, val loss: 1.6849465370178223
# Epoch 348, train loss: 3.924365120366457e-05, val loss: 1.6903488636016846
# Epoch 349, train loss: 8.040435824551862e-05, val loss: 1.7276653051376343
# Epoch 350, train loss: 0.00011402624012488458, val loss: 1.746302604675293
# Epoch 351, train loss: 6.032121166720538e-05, val loss: 1.6746101379394531
# Epoch 352, train loss: 1.9694592319191777e-05, val loss: 1.6065856218338013
# Epoch 353, train loss: 2.4969352293906183e-05, val loss: 1.6270805597305298
# Epoch 354, train loss: 1.813450142907203e-05, val loss: 1.6680564880371094
# Epoch 355, train loss: 1.6429764771062225e-05, val loss: 1.6847978830337524
# Epoch 356, train loss: 2.0834507166808988e-05, val loss: 1.693076252937317
# Epoch 357, train loss: 2.4664096566050796e-05, val loss: 1.687588095664978
# Epoch 358, train loss: 2.4449076253976846e-05, val loss: 1.672041893005371
# Epoch 359, train loss: 2.1854409539998784e-05, val loss: 1.6658910512924194
# Epoch 360, train loss: 1.8642485951271805e-05, val loss: 1.6585875749588013
# Epoch 361, train loss: 1.5784204016974264e-05, val loss: 1.6520143747329712
# Epoch 362, train loss: 1.4407405884682063e-05, val loss: 1.6489331722259521
# Epoch 363, train loss: 1.4352559918296282e-05, val loss: 1.6436375379562378
# Epoch 364, train loss: 1.515550475569735e-05, val loss: 1.6345075368881226
# Epoch 365, train loss: 1.6417048148772057e-05, val loss: 1.6259551048278809
# Epoch 366, train loss: 1.7888929842565967e-05, val loss: 1.6133618354797363
# Epoch 367, train loss: 1.9454969097515225e-05, val loss: 1.5986076593399048
# Epoch 368, train loss: 2.1009736411980595e-05, val loss: 1.5837650299072266
# Epoch 369, train loss: 2.2852121791974815e-05, val loss: 1.5698920488357544
# Epoch 370, train loss: 2.4898548064003182e-05, val loss: 1.5545008182525635
# Epoch 371, train loss: 2.7530119512920027e-05, val loss: 1.5400917530059814
# Epoch 372, train loss: 3.084729272544522e-05, val loss: 1.5241615772247314
# Epoch 373, train loss: 3.6328456189949065e-05, val loss: 1.501715064048767
# Epoch 374, train loss: 4.637717089887398e-05, val loss: 1.4812524318695068
# Epoch 375, train loss: 7.123585560798852e-05, val loss: 1.4594358205795288
# Epoch 376, train loss: 0.00014132978928197795, val loss: 1.4609243869781494
# Epoch 377, train loss: 0.00026295940592212393, val loss: 1.5001345872879028
# Epoch 378, train loss: 0.00018961239186831303, val loss: 1.322135329246521
# Epoch 379, train loss: 0.00011769925132048902, val loss: 1.254650354385376
# Epoch 380, train loss: 0.00010370325132195528, val loss: 1.2992326021194458
# Epoch 381, train loss: 8.481562906160468e-05, val loss: 1.3224812746047974
# Epoch 382, train loss: 7.421009178398419e-05, val loss: 1.3433750867843628
# Epoch 383, train loss: 5.1317562018219314e-05, val loss: 1.3968451023101807
# Epoch 384, train loss: 3.5196136094681504e-05, val loss: 1.4590935707092285
# Epoch 385, train loss: 2.6070588555066258e-05, val loss: 1.5049775838851929
# Epoch 386, train loss: 2.061870509351138e-05, val loss: 1.5385611057281494
# Epoch 387, train loss: 1.7707165574797222e-05, val loss: 1.558501124382019
# Epoch 388, train loss: 1.5479052982064552e-05, val loss: 1.5681403875350952
# Epoch 389, train loss: 1.4227863007194915e-05, val loss: 1.572503924369812
# Epoch 390, train loss: 1.3797656922381268e-05, val loss: 1.578420877456665
# Epoch 391, train loss: 1.3732371236848715e-05, val loss: 1.5802247524261475
# Epoch 392, train loss: 1.3864909272308944e-05, val loss: 1.5833300352096558
# Epoch 393, train loss: 1.4228975420270149e-05, val loss: 1.5925300121307373
# Epoch 394, train loss: 1.4955117741785082e-05, val loss: 1.5992765426635742
# Epoch 395, train loss: 1.6293576495458923e-05, val loss: 1.6018470525741577
# Epoch 396, train loss: 1.8674798815886283e-05, val loss: 1.6037721633911133
# Epoch 397, train loss: 2.3263889589644452e-05, val loss: 1.6041362285614014
# Epoch 398, train loss: 3.180475539044926e-05, val loss: 1.6058381795883179
# Epoch 399, train loss: 4.556013718010271e-05, val loss: 1.61012864112854
# Epoch 400, train loss: 6.189195900569084e-05, val loss: 1.6152695417404175
# Epoch 401, train loss: 6.21385125769949e-05, val loss: 1.6185654401779175
# Epoch 402, train loss: 3.5089261911235994e-05, val loss: 1.5960817337036133
# Epoch 403, train loss: 1.5625374173935227e-05, val loss: 1.5671237707138062
# Epoch 404, train loss: 1.668072514736128e-05, val loss: 1.5579334497451782
# Epoch 405, train loss: 2.4301899800236612e-05, val loss: 1.5585652589797974
# Epoch 406, train loss: 2.9222510420368053e-05, val loss: 1.5652354955673218
# Epoch 407, train loss: 2.5926566498431686e-05, val loss: 1.5809153318405151
# Epoch 408, train loss: 1.9442617014175522e-05, val loss: 1.5809080600738525
# Epoch 409, train loss: 2.062356368157823e-05, val loss: 1.5654504299163818
# Epoch 410, train loss: 3.531170956126449e-05, val loss: 1.541887640953064
# Epoch 411, train loss: 6.580123226740398e-05, val loss: 1.5245163440704346
# Epoch 412, train loss: 9.578107899330832e-05, val loss: 1.5001713037490845
# Epoch 413, train loss: 8.091323090613716e-05, val loss: 1.4328974485397339
# Epoch 414, train loss: 5.591060929604013e-05, val loss: 1.3755193948745728
# Epoch 415, train loss: 6.158613029617334e-05, val loss: 1.3584190607070923
# Epoch 416, train loss: 7.122912938939407e-05, val loss: 1.3364924192428589
# Epoch 417, train loss: 7.584599343654527e-05, val loss: 1.3363884687423706
# Epoch 418, train loss: 7.957628959384574e-05, val loss: 1.3316848278045654
# Epoch 419, train loss: 8.916519059480547e-05, val loss: 1.3206201791763306
# Epoch 420, train loss: 9.622533252695575e-05, val loss: 1.3154900074005127
# Epoch 421, train loss: 8.996108603982807e-05, val loss: 1.3364046812057495
# Epoch 422, train loss: 7.018752108302174e-05, val loss: 1.365309715270996
# Epoch 423, train loss: 4.53909914439363e-05, val loss: 1.4092366695404053
# Epoch 424, train loss: 2.9390654836552806e-05, val loss: 1.4647021293640137
# Epoch 425, train loss: 2.1767903726194397e-05, val loss: 1.5068248510360718
# Epoch 426, train loss: 1.8620672832454415e-05, val loss: 1.537108063697815
# Epoch 427, train loss: 1.7554484926491836e-05, val loss: 1.560254693031311
# Epoch 428, train loss: 1.641745472658874e-05, val loss: 1.575016975402832
# Epoch 429, train loss: 1.5251510746936589e-05, val loss: 1.5871047973632812
# Epoch 430, train loss: 1.4556450440539737e-05, val loss: 1.598016381263733
# Epoch 431, train loss: 1.4609026644999782e-05, val loss: 1.603859543800354
# Epoch 432, train loss: 1.583161947901654e-05, val loss: 1.6132678985595703
# Epoch 433, train loss: 1.9263612422811867e-05, val loss: 1.617940068244934
# Epoch 434, train loss: 2.7108620930381153e-05, val loss: 1.6198159456253052
# Epoch 435, train loss: 4.4862709896902e-05, val loss: 1.624314308166504
# Epoch 436, train loss: 7.940331946614336e-05, val loss: 1.6435117721557617
# Epoch 437, train loss: 0.00011275377996584953, val loss: 1.672764539718628
# Epoch 438, train loss: 7.722600195039477e-05, val loss: 1.646834135055542
# Epoch 439, train loss: 2.1073562931161615e-05, val loss: 1.5864994525909424
# Epoch 440, train loss: 3.568897530688749e-05, val loss: 1.594312071800232
# Epoch 441, train loss: 3.4945917461839226e-05, val loss: 1.6139801740646362
# Epoch 442, train loss: 1.9729250265367295e-05, val loss: 1.6209867000579834
# Epoch 443, train loss: 1.6326845811649776e-05, val loss: 1.628688097000122
# Epoch 444, train loss: 2.1266756313572706e-05, val loss: 1.6085598468780518
# Epoch 445, train loss: 1.8728783861324364e-05, val loss: 1.5907164812088013
# Epoch 446, train loss: 1.4725432265549898e-05, val loss: 1.5904090404510498
# Epoch 447, train loss: 1.1650972333478017e-05, val loss: 1.5877896547317505
# Epoch 448, train loss: 1.079836153992262e-05, val loss: 1.5840519666671753
# Epoch 449, train loss: 1.2477872183404139e-05, val loss: 1.583896517753601
# Epoch 450, train loss: 1.7091440962825868e-05, val loss: 1.5858569145202637
# Epoch 451, train loss: 2.5635651750403837e-05, val loss: 1.587744951248169
# Epoch 452, train loss: 3.50852405972546e-05, val loss: 1.589229941368103
# Epoch 453, train loss: 3.380216548976023e-05, val loss: 1.591386318206787
# Epoch 454, train loss: 2.0850419349261318e-05, val loss: 1.595331072807312
# Epoch 455, train loss: 1.8460884516739667e-05, val loss: 1.5917919874191284
# Epoch 456, train loss: 4.052841911659386e-05, val loss: 1.5804818868637085
# Epoch 457, train loss: 8.30833415858689e-05, val loss: 1.5799009799957275
# Epoch 458, train loss: 0.00010234007802662543, val loss: 1.586347222328186
# Epoch 459, train loss: 4.512836851602144e-05, val loss: 1.529505968093872
# Epoch 460, train loss: 2.398592901213474e-05, val loss: 1.4963940382003784
# Epoch 461, train loss: 3.184861122496875e-05, val loss: 1.4903219938278198
# Epoch 462, train loss: 2.5832984613737574e-05, val loss: 1.4671423435211182
# Epoch 463, train loss: 1.988854873397267e-05, val loss: 1.4619429111480713
# Epoch 464, train loss: 2.4490872925121545e-05, val loss: 1.4686200618743896
# Epoch 465, train loss: 3.299711331945016e-05, val loss: 1.4611300230026245
# Epoch 466, train loss: 3.7392500854804425e-05, val loss: 1.451625943183899
# Epoch 467, train loss: 4.060637109904309e-05, val loss: 1.435433030128479
# Epoch 468, train loss: 4.443026786989153e-05, val loss: 1.398443579673767
# Epoch 469, train loss: 5.089995991309277e-05, val loss: 1.350681185722351
# Epoch 470, train loss: 6.079644245565524e-05, val loss: 1.2980002164840698
# Epoch 471, train loss: 7.207595249551728e-05, val loss: 1.2576231956481934
# Epoch 472, train loss: 8.536965954893579e-05, val loss: 1.230048418045044
# Epoch 473, train loss: 0.00010202458280319761, val loss: 1.2122021913528442
# Epoch 474, train loss: 0.000126111722406845, val loss: 1.1984589099884033
# Epoch 475, train loss: 0.0001513946818131781, val loss: 1.1767655611038208
# Epoch 476, train loss: 0.00015757378531378453, val loss: 1.202199935913086
# Epoch 477, train loss: 0.00013345995399436947, val loss: 1.2803858518600464
# Epoch 478, train loss: 7.840656636054282e-05, val loss: 1.376668095588684
# Epoch 479, train loss: 3.2349033062928356e-05, val loss: 1.4657784700393677
# Epoch 480, train loss: 2.4279188100653874e-05, val loss: 1.528079867362976
# Epoch 481, train loss: 3.0506906451019285e-05, val loss: 1.5492678880691528
# Epoch 482, train loss: 3.088528474445748e-05, val loss: 1.555490255355835
# Epoch 483, train loss: 2.176523358448995e-05, val loss: 1.5628224611282349
# Epoch 484, train loss: 1.5898063860799152e-05, val loss: 1.562774419784546
# Epoch 485, train loss: 1.8818072257326328e-05, val loss: 1.5566481351852417
# Epoch 486, train loss: 2.283705267742604e-05, val loss: 1.55838942527771
# Epoch 487, train loss: 2.1760143513179003e-05, val loss: 1.5543867349624634
# Epoch 488, train loss: 1.7173692632005207e-05, val loss: 1.5504117012023926
# Epoch 489, train loss: 1.3141366623501569e-05, val loss: 1.5489647388458252
# Epoch 490, train loss: 1.1529970328815074e-05, val loss: 1.5464555025100708
# Epoch 491, train loss: 1.543989620350422e-05, val loss: 1.5465812683105469
# Epoch 492, train loss: 2.894059758141844e-05, val loss: 1.546891450881958
# Epoch 493, train loss: 5.365040110687173e-05, val loss: 1.5389292240142822
# Epoch 494, train loss: 6.693502587882836e-05, val loss: 1.5343451499938965
# Epoch 495, train loss: 3.908874741345817e-05, val loss: 1.5498759746551514
# Epoch 496, train loss: 3.0451547462251727e-05, val loss: 1.557571291923523
# Epoch 497, train loss: 6.694353497651819e-05, val loss: 1.5508573055267334
# Epoch 498, train loss: 7.543313828743219e-05, val loss: 1.543182373046875
# Epoch 499, train loss: 3.226815270964936e-05, val loss: 1.525429129600525
# Epoch 500, train loss: 1.5354742976746315e-05, val loss: 1.5146174430847168
# Epoch 501, train loss: 2.4230668916263516e-05, val loss: 1.522546648979187
# Epoch 502, train loss: 2.2678285218986543e-05, val loss: 1.5389412641525269
# Epoch 503, train loss: 1.5119120116988025e-05, val loss: 1.5494661331176758
# Epoch 504, train loss: 1.8756635283891768e-05, val loss: 1.5389623641967773
# Epoch 505, train loss: 2.499491098138538e-05, val loss: 1.5140635967254639
# Epoch 506, train loss: 2.370235792854887e-05, val loss: 1.497670292854309
# Epoch 507, train loss: 1.9373336827912783e-05, val loss: 1.484643578529358
# Epoch 508, train loss: 1.6298396076308563e-05, val loss: 1.4709223508834839
# Epoch 509, train loss: 1.6458553579502256e-05, val loss: 1.4615750312805176
# Epoch 510, train loss: 1.9991813705591658e-05, val loss: 1.4515739679336548
# Epoch 511, train loss: 2.753121589194052e-05, val loss: 1.4403481483459473
# Epoch 512, train loss: 3.9650263917994583e-05, val loss: 1.4289236068725586
# Epoch 513, train loss: 4.9372449009549906e-05, val loss: 1.4208135604858398
# Epoch 514, train loss: 4.5677657773787224e-05, val loss: 1.4073731899261475
# Epoch 515, train loss: 4.219979032145434e-05, val loss: 1.3910871744155884
# Epoch 516, train loss: 6.797461564592258e-05, val loss: 1.3764759302139282
# Epoch 517, train loss: 0.00012645498564880755, val loss: 1.3750720024108887
# Epoch 518, train loss: 0.00015366790143566, val loss: 1.3491191864013672
# Epoch 519, train loss: 9.201424648010827e-05, val loss: 1.2904596328735352
# Epoch 520, train loss: 7.571156634690447e-05, val loss: 1.2988712787628174
# Epoch 521, train loss: 6.087180170450463e-05, val loss: 1.3444602489471436
# Epoch 522, train loss: 5.012213242244562e-05, val loss: 1.3753938674926758
# Epoch 523, train loss: 3.944067544512951e-05, val loss: 1.3998186588287354
# Epoch 524, train loss: 3.2039924917626195e-05, val loss: 1.4226367473602295
# Epoch 525, train loss: 2.3480549282760842e-05, val loss: 1.431252121925354
# Epoch 526, train loss: 1.6722866011723118e-05, val loss: 1.4537324905395508
# Epoch 527, train loss: 1.453281166269099e-05, val loss: 1.461260199546814
# Epoch 528, train loss: 1.587249850369214e-05, val loss: 1.4634273052215576
# Epoch 529, train loss: 2.0177421565340074e-05, val loss: 1.4664274454116821
# Epoch 530, train loss: 2.383910402756926e-05, val loss: 1.4717332124710083
# Epoch 531, train loss: 2.2073732233601966e-05, val loss: 1.4795502424240112
# Epoch 532, train loss: 1.5401692912241237e-05, val loss: 1.4871799945831299
# Epoch 533, train loss: 1.4964688792436695e-05, val loss: 1.494338035583496
# Epoch 534, train loss: 2.531996485938887e-05, val loss: 1.5024460554122925
# Epoch 535, train loss: 4.446000982877902e-05, val loss: 1.5226057767868042
# Epoch 536, train loss: 6.136724368843716e-05, val loss: 1.5377711057662964
# Epoch 537, train loss: 5.108432082192006e-05, val loss: 1.53510582447052
# Epoch 538, train loss: 2.3457673469911917e-05, val loss: 1.508658766746521
# Epoch 539, train loss: 1.503937312884739e-05, val loss: 1.4884153604507446
# Epoch 540, train loss: 2.853355073495078e-05, val loss: 1.4839681386947632
# Epoch 541, train loss: 4.369940857200331e-05, val loss: 1.486086130142212
# Epoch 542, train loss: 3.2287238961240895e-05, val loss: 1.4978159666061401
# Epoch 543, train loss: 1.737288834259811e-05, val loss: 1.5116727352142334
# Epoch 544, train loss: 2.9657079654431005e-05, val loss: 1.501975178718567
# Epoch 545, train loss: 4.365481880894448e-05, val loss: 1.489289402961731
# Epoch 546, train loss: 3.775762093870004e-05, val loss: 1.4725115299224854
# Epoch 547, train loss: 2.161254438019737e-05, val loss: 1.4495668411254883
# Epoch 548, train loss: 1.83691054526544e-05, val loss: 1.4313939809799194
# Epoch 549, train loss: 2.6098861578955417e-05, val loss: 1.410418152809143
# Epoch 550, train loss: 3.5788398101296344e-05, val loss: 1.4055536985397339
# Epoch 551, train loss: 3.291464168729295e-05, val loss: 1.409826397895813
# Epoch 552, train loss: 2.536040146541954e-05, val loss: 1.4105311632156372
# Epoch 553, train loss: 3.3366384741384536e-05, val loss: 1.4118635654449463
# Epoch 554, train loss: 5.73510127045059e-05, val loss: 1.4129568338394165
# Epoch 555, train loss: 8.002459664432401e-05, val loss: 1.3983334302902222
# Epoch 556, train loss: 8.241088518709014e-05, val loss: 1.350964903831482
# Epoch 557, train loss: 7.394676746722932e-05, val loss: 1.2846599817276
# Epoch 558, train loss: 7.487348975027325e-05, val loss: 1.2299963235855103
# Epoch 559, train loss: 7.995577012749251e-05, val loss: 1.2107025384902954
# Epoch 560, train loss: 7.928645478656378e-05, val loss: 1.2157344818115234
# Epoch 561, train loss: 7.32389356320103e-05, val loss: 1.2337684631347656
# Epoch 562, train loss: 6.862570592568739e-05, val loss: 1.2564183473587036
# Epoch 563, train loss: 6.667429894420181e-05, val loss: 1.2837868928909302
# Epoch 564, train loss: 6.555768642876367e-05, val loss: 1.3348941802978516
# Epoch 565, train loss: 5.639346825234868e-05, val loss: 1.3849543333053589
# Epoch 566, train loss: 3.4001697780762765e-05, val loss: 1.4196908473968506
# Epoch 567, train loss: 1.852434272425146e-05, val loss: 1.435515284538269
# Epoch 568, train loss: 2.63849873321036e-05, val loss: 1.4389885663986206
# Epoch 569, train loss: 4.817135575447335e-05, val loss: 1.4510352611541748
# Epoch 570, train loss: 4.926561571968099e-05, val loss: 1.471800446510315
# Epoch 571, train loss: 2.4437617227064306e-05, val loss: 1.4867194890975952
# Epoch 572, train loss: 1.9900818086979496e-05, val loss: 1.494423270225525
# Epoch 573, train loss: 2.7535996465572948e-05, val loss: 1.497482180595398
# Epoch 574, train loss: 2.459701843488599e-05, val loss: 1.503584623336792
# Early stopping!

# %%
# Calculate the reconstruction error for test_data
test_data_reconstructed = model(test_data_scaled)
# test_data_reconstructed

# %%
reconstruction_error = torch.mean(torch.square(test_data_scaled - test_data_reconstructed), axis=1)
# reconstruction_error

# %%
# 인덱스별 reconstruction_error 값을 그래프로 그립니다.
plt.figure(figsize=(100,6))
plt.xticks(np.arange(0, 1296, 10))
plt.plot(range(len(reconstruction_error)), reconstruction_error.detach().numpy())
plt.title("Reconstruction Error by Index")
plt.xlabel("Index")
plt.ylabel("Reconstruction Error")
plt.show()

# %%
# 인덱스 범위를 설정하여 reconstruction_error 값을 그래프로 그립니다.
start_index = 580
end_index = 730
plt.figure(figsize=(40,6))
# plt.axhline(y=z, color='r', linestyle='--')
plt.xticks(np.arange(start_index, end_index, 2))
plt.plot(range(start_index, end_index), reconstruction_error[start_index:end_index].detach().numpy())
plt.title("Reconstruction Error by Index")
plt.xlabel("Index")
plt.ylabel("Reconstruction Error")
plt.show()

# %%
# 527이 이상함
start_idx = 0
end_idx = 238
reconstruction_error_max = torch.max(reconstruction_error[start_idx:end_idx+1])

x = float(reconstruction_error_max)
x
# Out:
# 0.0002935637312475592

# %%
start_idx = 246
end_idx = 247
reconstruction_error_mean = torch.mean(reconstruction_error[start_idx:end_idx+1])

z = float(reconstruction_error_mean)
z
# Out:
# 0.5255482196807861

# %%
start_idx = 0
end_idx = 610
reconstruction_error_max = torch.max(reconstruction_error[start_idx:end_idx+1])

y = float(reconstruction_error_max)
y
# Out:
# 0.05606292933225632

# %%
# Set a threshold for considering a test point as an anomaly
threshold = np.percentile(reconstruction_error.detach().numpy(), 85.2547)
threshold
# Out:
# 0.056614397305584305

# %%
# Predict anomalies in test_data
test_prediction6 = (reconstruction_error.detach().numpy() > threshold).astype(int)

# %% [markdown]
# # 데이터 저장

# %%
from collections import Counter

count = Counter(test_prediction6)
num_0 = count[0]
num_1 = count[1]

print("Number of 0s: ", num_0)
print("Number of 1s: ", num_1)
# Out:
# Number of 0s:  637
# Number of 1s:  110

# %%
file_name = model_name + '_th852547'

# %%
# 코랩에 저장
idx = test_data.loc[:, 'type']
y_pred = {'type': idx, 'label': test_prediction6}
test_prediction = pd.DataFrame(y_pred)
test_prediction.to_csv(f"{file_name}.csv")

# %%
# 가중치 추출
encoder_weights = model.encoder[0].weight.data.numpy()
decoder_weights = model.decoder[0].weight.data.numpy()

# 각 feature의 중요도 계산
importance = np.abs(np.vstack([encoder_weights, decoder_weights[:, :54]])).sum(axis=0)

# 중요도가 높은 feature 순서대로 출력
sorted_idx = np.argsort(importance)[::-1]
feature_names = df_test.columns  # 입력 데이터의 각 열에 대한 이름 리스트
sorted_feature_names = [feature_names[idx] for idx in sorted_idx]
sorted_importance = importance[sorted_idx]

# 중요도가 높은 feature 순서대로 그래프 그리기
plt.figure(figsize=(10, 20))
sns.barplot(y=sorted_feature_names, x=sorted_importance)
plt.ylabel("Features")
plt.xlabel("Importance")
plt.show()
